# %%
import pandas as pd
import numpy as np

# %%
movies=pd.read_csv('data/movie.csv')
ratings=pd.read_csv('data/rating.csv')
genome=pd.read_csv('data/genome_scores.csv')
tags=pd.read_csv('data/tag.csv')

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
genome.columns
# Out:
# Index(['movieId', 'tagId', 'relevance'], dtype='object')

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
a=ratings['userId'].value_counts()

# %%
b=ratings['userId'].value_counts()>200

# %%
new_users=list(a[b].index)

# %%
len(new_users)
# Out:
# 26599

# %%
ratings=ratings[ratings['userId'].isin(new_users)]

# %%
ratings.head(3)
# Out:
#      userId  movieId  rating            timestamp
# 541       7        3     3.0  2002-01-16 19:14:23
# 542       7        7     3.0  2002-01-16 19:10:20
# 543       7       11     4.0  2002-01-16 19:04:49

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
movies_refine = movies.copy()
movies_refine['year'] = ((movies_refine['title'].str.extract(r'\((....)\) *$'))[0].astype('float32'))
movies_refine = movies_refine.dropna()
movies_refine['year'] = movies_refine['year'].astype('int32')
movies_refine['title'] = (movies_refine['title'].str.extract(r'^(.*) \(....\) *$'))[0]
movies_refine['genres'] = movies_refine['genres'].str.split('|')

movies_refine
# Out:
#        movieId                        title  \
# 0            1                    Toy Story
# 1            2                      Jumanji
# 2            3             Grumpier Old Men
# 3            4            Waiting to Exhale
# 4            5  Father of the Bride Part II
# ...        ...                          ...
# 27273   131254        Kein Bund für's Leben
# 27274   131256       Feuer, Eis & Dosenbier
# 27275   131258                  The Pirates
# 27276   131260                 Rentun Ruusu
# 27277   131262                    Innocence
#
#                                                   genres  year
# 0      [Adventure, Animation, Children, Comedy, Fantasy]  1995
# 1                         [Adventure, Children, Fantasy]  1995
# 2                                      [Comedy, Romance]  1995
# 3                               [Comedy, Drama, Romance]  1995
# 4                                               [Comedy]  1995
# ...                                                  ...   ...
# 27273                                           [Comedy]  2007
# 27274                                           [Comedy]  2002
# 27275                                        [Adventure]  2014
# 27276                               [(no genres listed)]  2001
# 27277                       [Adventure, Fantasy, Horror]  2014
#
# [27252 rows x 4 columns]

# %%
ratings_with_moviename = ratings.merge(movies_refine, on='movieId')

# %%
ratings_with_moviename.shape
# Out:
# (12426038, 7)

# %%
ratings_with_moviename.head()
# Out:
#    userId  movieId  rating            timestamp             title  \
# 0       7        3     3.0  2002-01-16 19:14:23  Grumpier Old Men
# 1      91        3     3.0  2005-03-22 22:43:12  Grumpier Old Men
# 2      96        3     4.0  2013-06-13 02:18:47  Grumpier Old Men
# 3     116        3     2.0  2005-11-23 06:40:58  Grumpier Old Men
# 4     156        3     2.0  2002-12-02 03:53:45  Grumpier Old Men
#
#               genres  year
# 0  [Comedy, Romance]  1995
# 1  [Comedy, Romance]  1995
# 2  [Comedy, Romance]  1995
# 3  [Comedy, Romance]  1995
# 4  [Comedy, Romance]  1995

# %%
genre_count = dict()
for index, series in movies_refine.iterrows():
    for genre in series['genres']:
        genre_count[genre] = genre_count.get(genre, 0) + 1
print(genre_count)
# Out:
# {'Adventure': 2329, 'Animation': 1026, 'Children': 1139, 'Comedy': 8369, 'Fantasy': 1411, 'Romance': 4127, 'Drama': 13337, 'Action': 3518, 'Crime': 2938, 'Thriller': 4177, 'Horror': 2611, 'Mystery': 1513, 'Sci-Fi': 1740, 'IMAX': 196, 'Documentary': 2467, 'War': 1194, 'Musical': 1034, 'Western': 676, 'Film-Noir': 330, '(no genres listed)': 237}

# %%
len(genre_count)
# Out:
# 20

# %%
movie_num_rating=ratings_with_moviename.groupby('title')['rating'].count().reset_index()

# %%
movie_num_rating.rename(columns={'rating':'num_ratings'},inplace=True)

# %%
movie_num_rating=movie_num_rating[movie_num_rating['num_ratings']>=50]

# %%
final_rating=ratings_with_moviename.merge(movie_num_rating,on='title')

# %%
final_rating
# Out:
#           userId  movieId  rating            timestamp             title  \
# 0              7        3     3.0  2002-01-16 19:14:23  Grumpier Old Men
# 1             91        3     3.0  2005-03-22 22:43:12  Grumpier Old Men
# 2             96        3     4.0  2013-06-13 02:18:47  Grumpier Old Men
# 3            116        3     2.0  2005-11-23 06:40:58  Grumpier Old Men
# 4            156        3     2.0  2002-12-02 03:53:45  Grumpier Old Men
# ...          ...      ...     ...                  ...               ...
# 12278100  134567    69088     3.5  2011-12-07 12:54:03     War Game, The
# 12278101  137202    69088     4.0  2012-01-03 04:19:44     War Game, The
# 12278102  137425    69088     3.0  2010-11-28 21:25:04     War Game, The
# 12278103  137996    69088     4.0  2011-08-29 19:59:35     War Game, The
# 12278104  138325    69088     4.5  2011-01-03 19:57:35     War Game, The
#
#                              genres  year  num_ratings
# 0                 [Comedy, Romance]  1995         4665
# 1                 [Comedy, Romance]  1995         4665
# 2                 [Comedy, Romance]  1995         4665
# 3                 [Comedy, Romance]  1995         4665
# 4                 [Comedy, Romance]  1995         4665
# ...                             ...   ...          ...
# 12278100  [Documentary, Drama, War]  1965           51
# 12278101  [Documentary, Drama, War]  1965           51
# 12278102  [Documentary, Drama, War]  1965           51
# 12278103  [Documentary, Drama, War]  1965           51
# 12278104  [Documentary, Drama, War]  1965           51
#
# [12278105 rows x 8 columns]

# %%
final_rating=final_rating.drop_duplicates(subset=['userId','title'])

# %%
final_rating.shape
# Out:
# (12215635, 8)

# %%
movie_pivot=final_rating.pivot_table(columns='userId',index='title',values='rating')

# %%
movie_pivot.shape
# Out:
# (9777, 26599)

# %%
movie_pivot=movie_pivot.fillna(0)

# %%
movie_pivot
# Out:
# userId                                  7       11      14      24      \
# title
# 'Round Midnight                            0.0     0.0     0.0     0.0
# 'Salem's Lot                               0.0     0.0     0.0     0.0
# 'Til There Was You                         0.0     0.0     0.0     0.0
# 'burbs, The                                0.0     0.0     0.0     0.0
# 'night Mother                              0.0     0.0     0.0     0.0
# ...                                        ...     ...     ...     ...
# loudQUIETloud: A Film About the Pixies     0.0     0.0     0.0     0.0
# xXx                                        0.0     0.0     0.0     0.0
# xXx: State of the Union                    0.0     0.0     0.0     0.0
# ¡Three Amigos!                             2.0     0.0     0.0     0.0
# À nous la liberté (Freedom for Us)         0.0     0.0     0.0     0.0
#
# userId                                  31      53      54      58      \
# title
# 'Round Midnight                            0.0     0.0     0.0     0.0
# 'Salem's Lot                               0.0     0.0     0.0     0.0
# 'Til There Was You                         0.0     0.0     0.0     0.0
# 'burbs, The                                0.0     0.0     3.0     0.0
# 'night Mother                              0.0     0.0     0.0     0.0
# ...                                        ...     ...     ...     ...
# loudQUIETloud: A Film About the Pixies     0.0     0.0     0.0     0.0
# xXx                                        0.0     0.0     0.0     0.0
# xXx: State of the Union                    0.0     0.0     0.0     0.0
# ¡Three Amigos!                             0.0     0.0     3.0     0.0
# À nous la liberté (Freedom for Us)         0.0     0.0     0.0     0.0
#
# userId                                  69      82      ...  138456  138457  \
# title                                                   ...
# 'Round Midnight                            0.0     0.0  ...     0.0     0.0
# 'Salem's Lot                               0.0     0.0  ...     0.0     0.0
# 'Til There Was You                         0.0     0.0  ...     0.0     0.0
# 'burbs, The                                0.0     0.0  ...     3.0     3.0
# 'night Mother                              0.0     0.0  ...     0.0     0.0
# ...                                        ...     ...  ...     ...     ...
# loudQUIETloud: A Film About the Pixies     0.0     0.0  ...     0.0     0.0
# xXx                                        0.0     0.0  ...     0.0     0.0
# xXx: State of the Union                    0.0     0.0  ...     0.0     0.0
# ¡Three Amigos!                             0.0     0.0  ...     0.0     0.0
# À nous la liberté (Freedom for Us)         0.0     0.0  ...     0.0     0.0
#
# userId                                  138459  138464  138467  138472  \
# title
# 'Round Midnight                            0.0     0.0     0.0     0.0
# 'Salem's Lot                               0.0     0.0     0.0     0.0
# 'Til There Was You                         0.0     0.0     0.0     0.0
# 'burbs, The                                0.0     0.0     0.0     0.0
# 'night Mother                              0.0     0.0     0.0     0.0
# ...                                        ...     ...     ...     ...
# loudQUIETloud: A Film About the Pixies     0.0     0.0     0.0     0.0
# xXx                                        0.0     0.0     0.0     0.0
# xXx: State of the Union                    0.0     0.0     0.0     0.0
# ¡Three Amigos!                             0.0     0.0     0.0     0.0
# À nous la liberté (Freedom for Us)         0.0     0.0     0.0     0.0
#
# userId                                  138474  138477  138483  138493
# title
# 'Round Midnight                            0.0     0.0     0.0     0.0
# 'Salem's Lot                               0.0     0.0     0.0     0.0
# 'Til There Was You                         0.0     0.0     0.0     0.0
# 'burbs, The                                4.0     0.0     0.0     0.0
# 'night Mother                              0.0     0.0     0.0     0.0
# ...                                        ...     ...     ...     ...
# loudQUIETloud: A Film About the Pixies     0.0     0.0     0.0     0.0
# xXx                                        0.0     1.0     0.0     0.0
# xXx: State of the Union                    0.0     0.0     0.0     0.0
# ¡Three Amigos!                             0.0     0.0     0.0     0.0
# À nous la liberté (Freedom for Us)         0.0     0.0     0.0     0.0
#
# [9777 rows x 26599 columns]

# %%
from scipy.sparse import csr_matrix
movie_matrix=csr_matrix(movie_pivot)
movie_matrix
# Out:
# <9777x26599 sparse matrix of type '<class 'numpy.float64'>'
# 	with 12215635 stored elements in Compressed Sparse Row format>

# %%
from sklearn.neighbors import NearestNeighbors

# %%
model=NearestNeighbors(algorithm='brute')

# %%
model.fit(movie_matrix)
# Out:
# NearestNeighbors(algorithm='brute', leaf_size=30, metric='minkowski',
#                  metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                  radius=1.0)

# %%
movie_pivot
# Out:
# userId                                  7       11      14      24      \
# title
# 'Round Midnight                            0.0     0.0     0.0     0.0
# 'Salem's Lot                               0.0     0.0     0.0     0.0
# 'Til There Was You                         0.0     0.0     0.0     0.0
# 'burbs, The                                0.0     0.0     0.0     0.0
# 'night Mother                              0.0     0.0     0.0     0.0
# ...                                        ...     ...     ...     ...
# loudQUIETloud: A Film About the Pixies     0.0     0.0     0.0     0.0
# xXx                                        0.0     0.0     0.0     0.0
# xXx: State of the Union                    0.0     0.0     0.0     0.0
# ¡Three Amigos!                             2.0     0.0     0.0     0.0
# À nous la liberté (Freedom for Us)         0.0     0.0     0.0     0.0
#
# userId                                  31      53      54      58      \
# title
# 'Round Midnight                            0.0     0.0     0.0     0.0
# 'Salem's Lot                               0.0     0.0     0.0     0.0
# 'Til There Was You                         0.0     0.0     0.0     0.0
# 'burbs, The                                0.0     0.0     3.0     0.0
# 'night Mother                              0.0     0.0     0.0     0.0
# ...                                        ...     ...     ...     ...
# loudQUIETloud: A Film About the Pixies     0.0     0.0     0.0     0.0
# xXx                                        0.0     0.0     0.0     0.0
# xXx: State of the Union                    0.0     0.0     0.0     0.0
# ¡Three Amigos!                             0.0     0.0     3.0     0.0
# À nous la liberté (Freedom for Us)         0.0     0.0     0.0     0.0
#
# userId                                  69      82      ...  138456  138457  \
# title                                                   ...
# 'Round Midnight                            0.0     0.0  ...     0.0     0.0
# 'Salem's Lot                               0.0     0.0  ...     0.0     0.0
# 'Til There Was You                         0.0     0.0  ...     0.0     0.0
# 'burbs, The                                0.0     0.0  ...     3.0     3.0
# 'night Mother                              0.0     0.0  ...     0.0     0.0
# ...                                        ...     ...  ...     ...     ...
# loudQUIETloud: A Film About the Pixies     0.0     0.0  ...     0.0     0.0
# xXx                                        0.0     0.0  ...     0.0     0.0
# xXx: State of the Union                    0.0     0.0  ...     0.0     0.0
# ¡Three Amigos!                             0.0     0.0  ...     0.0     0.0
# À nous la liberté (Freedom for Us)         0.0     0.0  ...     0.0     0.0
#
# userId                                  138459  138464  138467  138472  \
# title
# 'Round Midnight                            0.0     0.0     0.0     0.0
# 'Salem's Lot                               0.0     0.0     0.0     0.0
# 'Til There Was You                         0.0     0.0     0.0     0.0
# 'burbs, The                                0.0     0.0     0.0     0.0
# 'night Mother                              0.0     0.0     0.0     0.0
# ...                                        ...     ...     ...     ...
# loudQUIETloud: A Film About the Pixies     0.0     0.0     0.0     0.0
# xXx                                        0.0     0.0     0.0     0.0
# xXx: State of the Union                    0.0     0.0     0.0     0.0
# ¡Three Amigos!                             0.0     0.0     0.0     0.0
# À nous la liberté (Freedom for Us)         0.0     0.0     0.0     0.0
#
# userId                                  138474  138477  138483  138493
# title
# 'Round Midnight                            0.0     0.0     0.0     0.0
# 'Salem's Lot                               0.0     0.0     0.0     0.0
# 'Til There Was You                         0.0     0.0     0.0     0.0
# 'burbs, The                                4.0     0.0     0.0     0.0
# 'night Mother                              0.0     0.0     0.0     0.0
# ...                                        ...     ...     ...     ...
# loudQUIETloud: A Film About the Pixies     0.0     0.0     0.0     0.0
# xXx                                        0.0     1.0     0.0     0.0
# xXx: State of the Union                    0.0     0.0     0.0     0.0
# ¡Three Amigos!                             0.0     0.0     0.0     0.0
# À nous la liberté (Freedom for Us)         0.0     0.0     0.0     0.0
#
# [9777 rows x 26599 columns]

# %%
movie_pivot.iloc[237,:].values.reshape(1,-1)
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %%
distance,suggestion=model.kneighbors(movie_pivot.iloc[1,:].values.reshape(1,-1),n_neighbors=5)

# %%
suggestion
# Out:
# array([[   1, 4075, 6757, 8655, 3695]], dtype=int64)

# %%
movie_pivot.index[184]
# Out:
# 'Ace in the Hole (Big Carnival, The)'

# %%
for i in suggestion[0]:
    print(movie_pivot.index[i])
# Out:
# 'Salem's Lot
# Horrors of Spider Island (Ein Toter Hing im Netz)
# Piranha 3DD (a.k.a. Piranha DD)
# The Pumaman
# Grudge 3, The

# %%
np.where(movie_pivot.index=='Ace in the Hole (Big Carnival, The)')[0][0]
# Out:
# 184

# %%
def recommend(moviename):
    b_id=np.where(movie_pivot.index==moviename)[0][0]
    distance,suggestion=model.kneighbors(movie_pivot.iloc[b_id,:].values.reshape(1,-1),n_neighbors=5)
    for i in suggestion[0]:
        print(movie_pivot.index[i])

# %%
recommend('The Pumaman')
# Out:
# The Pumaman
# Horrors of Spider Island (Ein Toter Hing im Netz)
# Giant Spider Invasion, The
# Mitchell
# Beast of Yucca Flats, The
